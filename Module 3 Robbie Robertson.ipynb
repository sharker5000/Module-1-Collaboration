# %%
print(60 * 60)
# Out:
# 3600

# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour, "seconds per hour")
# Out:
# 3600 seconds per hour

# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour, "seconds per hour")
print(seconds_per_hour * 24)
# Out:
# 3600 seconds per hour
# 86400

# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour, "seconds per hour")
seconds_per_day = (seconds_per_hour * 24)
print(seconds_per_day, "seconds per day")
# Out:
# 3600 seconds per hour
# 86400 seconds per day

# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour, "seconds per hour")
seconds_per_day = (seconds_per_hour * 24)
print(seconds_per_day, "seconds per day")
print(seconds_per_hour / seconds_per_day)
# Out:
# 3600 seconds per hour
# 86400 seconds per day
# 0.041666666666666664

# %%
seconds_per_hour = (60 * 60)
print(seconds_per_hour, "seconds per hour")
seconds_per_day = (seconds_per_hour * 24)
print(seconds_per_day, "seconds per day")
print(seconds_per_hour // seconds_per_day)
# Out:
# 3600 seconds per hour
# 86400 seconds per day
# 0

# %% [markdown]
# No because the number is less than 1 so it is rounded down to a zero when divided as an integer.
